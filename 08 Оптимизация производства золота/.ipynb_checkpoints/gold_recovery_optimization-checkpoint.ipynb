# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Откройте-файлы-и-изучите-их" data-toc-modified-id="Откройте-файлы-и-изучите-их-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Откройте файлы и изучите их</a></span></li><li><span><a href="#Проверьте,-что-эффективность-обогащения-рассчитана-правильно.-Вычислите-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдите-MAE-между-вашими-расчётами-и-значением-признака.-Опишите-выводы" data-toc-modified-id="Проверьте,-что-эффективность-обогащения-рассчитана-правильно.-Вычислите-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдите-MAE-между-вашими-расчётами-и-значением-признака.-Опишите-выводы-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы</a></span></li><li><span><a href="#Проанализируйте-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?" data-toc-modified-id="Проанализируйте-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?</a></span></li><li><span><a href="#Проведите-предобработку-данных" data-toc-modified-id="Проведите-предобработку-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проведите предобработку данных</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Посмотрите,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-Опишите-выводы." data-toc-modified-id="Посмотрите,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-Опишите-выводы.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы.</a></span></li><li><span><a href="#Сравните-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной." data-toc-modified-id="Сравните-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.</a></span></li><li><span><a href="#Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах." data-toc-modified-id="Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Напишите-функцию-для-вычисления-итоговой-sMAPE." data-toc-modified-id="Напишите-функцию-для-вычисления-итоговой-sMAPE.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Напишите функцию для вычисления итоговой sMAPE.</a></span></li><li><span><a href="#Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы." data-toc-modified-id="Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Я подготовил прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Моя модель предсказывает коэффициент восстановления золота из золотосодержащей руды. Я использовал данные с параметрами добычи и очистки.
#
# Моя модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Для выполнения проекта я:
#
# 1. Подготовил данные;
# 2. Провел исследовательский анализ данных;
# 3. Построил и обучил модель.
#
# Чтобы выполнить проект, я обратился к библиотекам *pandas*, *matplotlib* и *sklearn.* Мне помогла их документация.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Откройте файлы и изучите их

# %%
# Я импортировал библиотеки
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import make_scorer
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import GridSearchCV

# %%
# Я загрузил данные из CSV файлов
data_train = pd.read_csv('../datasets/gold_industry_train.csv')
data_test = pd.read_csv('../datasets/gold_industry_test.csv')
data_full = pd.read_csv('../datasets/gold_industry_full.csv')

# %%
# Я использовал метод head() для быстрого просмотра первых строк данных data_train
data_train.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2016-01-15 00:00:00               6.486150               6.100378
# 1  2016-01-15 01:00:00               6.478583               6.161113
# 2  2016-01-15 02:00:00               6.362222               6.116455
# 3  2016-01-15 03:00:00               6.118189               6.043309
# 4  2016-01-15 04:00:00               5.663707               6.060915
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               2.284912               36.808594               523.546326
# 1               2.266033               35.753385               525.290581
# 2               2.159622               35.971630               530.026610
# 3               2.037807               36.862241               542.590390
# 4               1.786875               34.347666               540.531893
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# 0                55.486599                          11.986616
# 1                57.278666                          11.971193
# 2                57.510649                          11.920603
# 3                57.792734                          11.630094
# 4                56.047189                          10.957755
#
#    rougher.input.floatbank10_xanthate  rougher.state.floatbank10_a_air  ...  \
# 0                            6.007990                       999.706909  ...
# 1                            6.005766                      1000.286398  ...
# 2                            6.197377                       999.719565  ...
# 3                            6.203177                       999.814770  ...
# 4                            6.198826                       999.678690  ...
#
#    secondary_cleaner.output.tail_sol  final.output.concentrate_au  \
# 0                           8.764648                    42.192020
# 1                           9.001494                    42.701629
# 2                           8.842896                    42.657501
# 3                           9.122857                    42.689819
# 4                           8.871028                    42.774141
#
#    final.output.concentrate_ag  final.output.concentrate_pb  \
# 0                     6.055403                     9.889648
# 1                     6.029369                     9.968944
# 2                     6.055926                    10.213995
# 3                     6.047977                     9.977019
# 4                     6.148599                    10.142511
#
#    final.output.concentrate_sol  final.output.recovery  final.output.tail_au  \
# 0                      5.507324              70.541216              2.143149
# 1                      5.257781              69.266198              2.224930
# 2                      5.383759              68.116445              2.257889
# 3                      4.858634              68.347543              2.146849
# 4                      4.939416              66.927016              2.055292
#
#    final.output.tail_ag  final.output.tail_pb  final.output.tail_sol
# 0             10.411962              0.895447              16.904297
# 1             10.462676              0.927452              16.634514
# 2             10.507046              0.953716              16.208849
# 3             10.422762              0.883763              16.532835
# 4             10.360302              0.792826              16.525686
#
# [5 rows x 87 columns]

# %%
# Я использовал метод head() для быстрого просмотра первых строк данных data_test
data_test.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2017-12-09 14:59:59               4.365491               6.158718
# 1  2017-12-09 15:59:59               4.362781               6.048130
# 2  2017-12-09 16:59:59               5.081681               6.082745
# 3  2017-12-09 17:59:59               5.145949               6.084374
# 4  2017-12-09 18:59:59               5.735249               6.165220
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               3.875727               39.135119               555.820208
# 1               3.902537               39.713906               544.731687
# 2               4.564078               37.208683               558.155110
# 3               4.768124               36.808874               539.713765
# 4               4.512346               37.810642               558.713584
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# 0                94.544358                           6.146982
# 1               123.742430                           6.210119
# 2                82.610855                           7.363824
# 3                77.984784                           6.927072
# 4                86.434874                           7.823471
#
#    rougher.input.floatbank10_xanthate  rougher.state.floatbank10_a_air  ...  \
# 0                            9.308612                      1196.238112  ...
# 1                            9.297709                      1201.904177  ...
# 2                            9.003562                      1200.826926  ...
# 3                            8.955597                      1199.292489  ...
# 4                            7.490356                      1198.005449  ...
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 23.018622
# 1                                 23.024963
# 2                                 22.993827
# 3                                 23.032807
# 4                                 23.001911
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -500.492702
# 1                                 -501.153409
# 2                                 -501.559663
# 3                                 -501.287889
# 4                                 -499.947838
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                 20.020205
# 1                                 20.054122
# 2                                 20.029144
# 3                                 19.977466
# 4                                 20.023735
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -500.220296
# 1                                 -500.314711
# 2                                 -500.000662
# 3                                 -500.159903
# 4                                 -499.713680
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                 17.963512
# 1                                 17.979515
# 2                                 18.012723
# 3                                 17.980463
# 4                                 17.990955
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -499.939490
# 1                                 -499.272871
# 2                                 -500.024764
# 3                                 -500.504602
# 4                                 -500.334769
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                 12.990306
# 1                                 12.992404
# 2                                 13.016445
# 3                                 12.949071
# 4                                 13.007523
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.080993
# 1                                 -499.976268
# 2                                 -500.058432
# 3                                 -500.009937
# 4                                 -499.968459
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 19.990336
# 1                                 20.013986
# 2                                 19.973767
# 3                                 20.010332
# 4                                 19.995999
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -499.191575
# 1                                 -500.625471
# 2                                 -501.394155
# 3                                 -508.337973
# 4                                 -499.788805
#
# [5 rows x 53 columns]

# %%
# Я использовал метод head() для быстрого просмотра первых строк данных data_full
data_full.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2016-01-15 00:00:00               6.486150               6.100378
# 1  2016-01-15 01:00:00               6.478583               6.161113
# 2  2016-01-15 02:00:00               6.362222               6.116455
# 3  2016-01-15 03:00:00               6.118189               6.043309
# 4  2016-01-15 04:00:00               5.663707               6.060915
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               2.284912               36.808594               523.546326
# 1               2.266033               35.753385               525.290581
# 2               2.159622               35.971630               530.026610
# 3               2.037807               36.862241               542.590390
# 4               1.786875               34.347666               540.531893
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# 0                55.486599                          11.986616
# 1                57.278666                          11.971193
# 2                57.510649                          11.920603
# 3                57.792734                          11.630094
# 4                56.047189                          10.957755
#
#    rougher.input.floatbank10_xanthate  rougher.state.floatbank10_a_air  ...  \
# 0                            6.007990                       999.706909  ...
# 1                            6.005766                      1000.286398  ...
# 2                            6.197377                       999.719565  ...
# 3                            6.203177                       999.814770  ...
# 4                            6.198826                       999.678690  ...
#
#    secondary_cleaner.output.tail_sol  final.output.concentrate_au  \
# 0                           8.764648                    42.192020
# 1                           9.001494                    42.701629
# 2                           8.842896                    42.657501
# 3                           9.122857                    42.689819
# 4                           8.871028                    42.774141
#
#    final.output.concentrate_ag  final.output.concentrate_pb  \
# 0                     6.055403                     9.889648
# 1                     6.029369                     9.968944
# 2                     6.055926                    10.213995
# 3                     6.047977                     9.977019
# 4                     6.148599                    10.142511
#
#    final.output.concentrate_sol  final.output.recovery  final.output.tail_au  \
# 0                      5.507324              70.541216              2.143149
# 1                      5.257781              69.266198              2.224930
# 2                      5.383759              68.116445              2.257889
# 3                      4.858634              68.347543              2.146849
# 4                      4.939416              66.927016              2.055292
#
#    final.output.tail_ag  final.output.tail_pb  final.output.tail_sol
# 0             10.411962              0.895447              16.904297
# 1             10.462676              0.927452              16.634514
# 2             10.507046              0.953716              16.208849
# 3             10.422762              0.883763              16.532835
# 4             10.360302              0.792826              16.525686
#
# [5 rows x 87 columns]

# %%
# Я использовал метод describe() для получения основной статистической информации о числовых признаках в данных data_train
data_train.describe()
# Out:
#        rougher.input.feed_au  rougher.input.feed_ag  rougher.input.feed_pb  \
# count           14579.000000           14579.000000           14507.000000
# mean                8.352941               8.877460               3.604221
# std                 1.934376               1.922536               1.056063
# min                 0.010000               0.010000               0.010000
# 25%                 6.932996               7.341922               2.880490
# 50%                 8.225284               8.715859               3.532399
# 75%                 9.832210              10.255843               4.257282
# max                13.731330              14.596026               7.052325
#
#        rougher.input.feed_sol  rougher.input.feed_rate  \
# count            14502.000000             14572.000000
# mean                36.561420               474.332784
# std                  5.209823               108.503552
# min                  0.010000                 0.002986
# 25%                 34.093951               411.048483
# 50%                 37.097511               498.187968
# 75%                 39.899799               549.586552
# max                 53.475325               717.508837
#
#        rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# count             14478.000000                       14548.000000
# mean                 58.922712                          12.427399
# std                  22.407410                           3.428939
# min                   0.049194                           0.001083
# 25%                  47.278490                          10.002832
# 50%                  54.361187                          12.003320
# 75%                  64.464926                          14.929903
# max                 484.967466                          36.118275
#
#        rougher.input.floatbank10_xanthate  rougher.state.floatbank10_a_air  \
# count                        14572.000000                     14579.000000
# mean                             5.994854                      1104.208278
# std                              1.152873                       162.235606
# min                              0.000568                        -0.042069
# 25%                              5.304167                       999.644856
# 50%                              6.003053                      1000.982624
# 75%                              6.796632                      1292.663971
# max                              9.703448                      1512.299531
#
#        rougher.state.floatbank10_a_level  ...  \
# count                       14579.000000  ...
# mean                         -379.367166  ...
# std                            94.652311  ...
# min                          -657.949759  ...
# 25%                          -499.861797  ...
# 50%                          -300.314199  ...
# 75%                          -299.989315  ...
# max                          -273.776101  ...
#
#        secondary_cleaner.output.tail_sol  final.output.concentrate_au  \
# count                       13659.000000                 14579.000000
# mean                            7.111347                    43.979499
# std                             3.909951                     5.471437
# min                             0.000000                     0.000000
# 25%                             3.784897                    43.345906
# 50%                             7.629968                    44.975014
# 75%                            10.367050                    46.275153
# max                            26.000772                    52.756638
#
#        final.output.concentrate_ag  final.output.concentrate_pb  \
# count                 14578.000000                 14578.000000
# mean                      5.192145                     9.923809
# std                       1.388014                     1.706976
# min                       0.000000                     0.000000
# 25%                       4.283347                     9.103183
# 50%                       5.118647                    10.046455
# 75%                       5.925380                    10.981203
# max                      16.001945                    16.705297
#
#        final.output.concentrate_sol  final.output.recovery  \
# count                  14387.000000           14579.000000
# mean                       9.566676              66.759066
# std                        2.805654              10.619709
# min                        0.000000               0.000000
# 25%                        7.860030              63.114596
# 50%                        9.301970              67.962788
# 75%                       11.001573              72.598187
# max                       19.423912             100.000000
#
#        final.output.tail_au  final.output.tail_ag  final.output.tail_pb  \
# count          14579.000000          14578.000000          14504.000000
# mean               3.087939              9.731972              2.719985
# std                0.915187              2.358143              0.958929
# min                0.000000              0.000000              0.000000
# 25%                2.505287              8.088928              2.036512
# 50%                3.029238              9.818512              2.774847
# 75%                3.614098             11.169187              3.353845
# max                8.245022             19.552149              5.804178
#
#        final.output.tail_sol
# count           14574.000000
# mean               10.612745
# std                 2.871075
# min                 0.000000
# 25%                 9.013412
# 50%                10.670515
# 75%                12.130827
# max                22.317730
#
# [8 rows x 86 columns]

# %%
# Я использовал метод describe() для получения основной статистической информации о числовых признаках в данных data_test
data_test.describe()
# Out:
#        rougher.input.feed_au  rougher.input.feed_ag  rougher.input.feed_pb  \
# count            4860.000000            4860.000000            4832.000000
# mean                8.005584               8.547348               3.579662
# std                 1.993590               1.958601               1.029377
# min                 0.010000               0.010000               0.010000
# 25%                 6.574363               6.975898               2.903612
# 50%                 7.812923               8.179714               3.540772
# 75%                 9.556589              10.084339               4.199847
# max                13.417156              14.533698               7.142594
#
#        rougher.input.feed_sol  rougher.input.feed_rate  \
# count             4838.000000              4856.000000
# mean                37.095864               490.285103
# std                  4.926284                94.371623
# min                  0.010000                 0.012786
# 25%                 34.510841               434.099695
# 50%                 37.499761               502.118742
# 75%                 40.461315               555.596563
# max                 53.477742               702.523396
#
#        rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# count              4816.000000                        4857.000000
# mean                 59.113400                          12.055735
# std                  19.125122                           3.407642
# min                   0.046369                           0.018907
# 25%                  47.596984                           9.890429
# 50%                  55.509481                          11.997859
# 75%                  66.661547                          14.496072
# max                 363.989699                          30.010759
#
#        rougher.input.floatbank10_xanthate  rougher.state.floatbank10_a_air  \
# count                         4859.000000                      4859.000000
# mean                             6.101308                      1108.635895
# std                              1.042754                       156.493143
# min                              0.015783                       300.792494
# 25%                              5.499808                       999.715729
# 50%                              6.099805                      1001.414798
# 75%                              6.802101                      1202.837565
# max                              9.396928                      1521.980372
#
#        rougher.state.floatbank10_a_level  ...  \
# count                        4859.000000  ...
# mean                         -368.340127  ...
# std                            91.155929  ...
# min                          -600.568138  ...
# 25%                          -499.731972  ...
# 50%                          -300.181367  ...
# 75%                          -299.961547  ...
# max                          -281.039299  ...
#
#        secondary_cleaner.state.floatbank4_a_air  \
# count                              4.859000e+03
# mean                               1.985770e+01
# std                                5.913105e+00
# min                                1.079872e-16
# 25%                                1.501123e+01
# 50%                                1.996807e+01
# 75%                                2.498900e+01
# max                                3.008450e+01
#
#        secondary_cleaner.state.floatbank4_a_level  \
# count                                 4859.000000
# mean                                  -488.665140
# std                                     44.392714
# min                                   -799.704969
# 25%                                   -500.704004
# 50%                                   -499.892919
# 75%                                   -498.652030
# max                                   -383.373053
#
#        secondary_cleaner.state.floatbank4_b_air  \
# count                              4.859000e+03
# mean                               1.557025e+01
# std                                4.927361e+00
# min                                2.489718e-17
# 25%                                1.202172e+01
# 50%                                1.501240e+01
# 75%                                1.999949e+01
# max                                2.398898e+01
#
#        secondary_cleaner.state.floatbank4_b_level  \
# count                                 4859.000000
# mean                                  -464.176507
# std                                     65.706994
# min                                   -799.860767
# 25%                                   -500.196517
# 50%                                   -499.540776
# 75%                                   -400.302329
# max                                   -114.250832
#
#        secondary_cleaner.state.floatbank5_a_air  \
# count                               4859.000000
# mean                                  16.594103
# std                                    5.724305
# min                                   -0.371498
# 25%                                   11.073822
# 50%                                   16.631195
# 75%                                   19.983191
# max                                   33.215996
#
#        secondary_cleaner.state.floatbank5_a_level  \
# count                                 4859.000000
# mean                                  -490.815250
# std                                     32.258443
# min                                   -797.142475
# 25%                                   -500.483564
# 50%                                   -499.873136
# 75%                                   -498.852815
# max                                   -288.963521
#
#        secondary_cleaner.state.floatbank5_b_air  \
# count                               4859.000000
# mean                                  12.945971
# std                                    5.533176
# min                                    1.358469
# 25%                                    9.011890
# 50%                                   11.999417
# 75%                                   15.004198
# max                                   24.177106
#
#        secondary_cleaner.state.floatbank5_b_level  \
# count                                 4859.000000
# mean                                  -489.583564
# std                                     37.084609
# min                                   -800.006180
# 25%                                   -500.129913
# 50%                                   -499.955304
# 75%                                   -499.643776
# max                                   -141.934397
#
#        secondary_cleaner.state.floatbank6_a_air  \
# count                               4859.000000
# mean                                  19.053888
# std                                    5.548996
# min                                    0.160386
# 25%                                   14.963953
# 50%                                   19.960006
# 75%                                   24.974583
# max                                   32.028529
#
#        secondary_cleaner.state.floatbank6_a_level
# count                                 4859.000000
# mean                                  -504.678924
# std                                     38.690186
# min                                   -809.734800
# 25%                                   -500.668501
# 50%                                   -500.033769
# 75%                                   -499.460134
# max                                   -104.427459
#
# [8 rows x 52 columns]

# %%
# Я использовал метод describe() для получения основной статистической информации о числовых признаках в данных data_full
data_full.describe()
# Out:
#        rougher.input.feed_au  rougher.input.feed_ag  rougher.input.feed_pb  \
# count           19439.000000           19439.000000           19339.000000
# mean                8.266097               8.794927               3.598085
# std                 1.955092               1.936847               1.049486
# min                 0.010000               0.010000               0.010000
# 25%                 6.854384               7.237967               2.887280
# 50%                 8.125839               8.593574               3.534895
# 75%                 9.769917              10.213771               4.244161
# max                13.731330              14.596026               7.142594
#
#        rougher.input.feed_sol  rougher.input.feed_rate  \
# count            19340.000000             19428.000000
# mean                36.695114               478.320042
# std                  5.145445               105.373758
# min                  0.010000                 0.002986
# 25%                 34.207799               416.525453
# 50%                 37.202650               499.416120
# 75%                 40.039133               550.172183
# max                 53.477742               717.508837
#
#        rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# count             19294.000000                       19405.000000
# mean                 58.970310                          12.334373
# std                  21.634478                           3.427317
# min                   0.046369                           0.001083
# 25%                  47.435103                          10.000362
# 50%                  54.610197                          12.001174
# 75%                  65.023044                          14.716595
# max                 484.967466                          36.118275
#
#        rougher.input.floatbank10_xanthate  rougher.state.floatbank10_a_air  \
# count                        19431.000000                     19438.000000
# mean                             6.021474                      1105.315068
# std                              1.127263                       160.826798
# min                              0.000568                        -0.042069
# 25%                              5.398678                       999.661867
# 50%                              6.008273                      1001.072890
# 75%                              6.798051                      1205.620588
# max                              9.703448                      1521.980372
#
#        rougher.state.floatbank10_a_level  ...  \
# count                       19438.000000  ...
# mean                         -376.610690  ...
# std                            93.909667  ...
# min                          -657.949759  ...
# 25%                          -499.835165  ...
# 50%                          -300.263994  ...
# 75%                          -299.981998  ...
# max                          -273.776101  ...
#
#        secondary_cleaner.output.tail_sol  final.output.concentrate_au  \
# count                       17691.000000                 19439.000000
# mean                            7.167247                    44.076513
# std                             3.916079                     5.129784
# min                             0.000000                     0.000000
# 25%                             3.845475                    43.402215
# 50%                             7.685827                    45.011244
# 75%                            10.411296                    46.275313
# max                            26.000772                    52.756638
#
#        final.output.concentrate_ag  final.output.concentrate_pb  \
# count                 19438.000000                 19438.000000
# mean                      5.168470                     9.978895
# std                       1.372348                     1.669240
# min                       0.000000                     0.000000
# 25%                       4.251240                     9.137262
# 50%                       5.066094                    10.102433
# 75%                       5.895527                    11.035769
# max                      16.001945                    17.031899
#
#        final.output.concentrate_sol  final.output.recovery  \
# count                  19228.000000           19439.000000
# mean                       9.501224              67.050208
# std                        2.787537              10.125840
# min                        0.000000               0.000000
# 25%                        7.722820              63.299712
# 50%                        9.218961              68.172738
# 75%                       10.947813              72.686642
# max                       19.615720             100.000000
#
#        final.output.tail_au  final.output.tail_ag  final.output.tail_pb  \
# count          19439.000000          19438.000000          19338.000000
# mean               3.042467              9.688589              2.705795
# std                0.922808              2.328642              0.949077
# min                0.000000              0.000000              0.000000
# 25%                2.461138              8.062878              2.040119
# 50%                2.984909              9.743623              2.748730
# 75%                3.571351             11.134294              3.333216
# max                8.245022             19.552149              5.804178
#
#        final.output.tail_sol
# count           19433.000000
# mean               10.583728
# std                 2.868782
# min                 0.000000
# 25%                 8.938947
# 50%                10.622456
# 75%                12.104271
# max                22.317730
#
# [8 rows x 86 columns]

# %%
# Я вывел информацию о датасетах, используя метод info()
data_train.info()
data_test.info()
data_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14579 entries, 0 to 14578
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14579 non-null  object
#  1   rougher.input.feed_au                               14579 non-null  float64
#  2   rougher.input.feed_ag                               14579 non-null  float64
#  3   rougher.input.feed_pb                               14507 non-null  float64
#  4   rougher.input.feed_sol                              14502 non-null  float64
#  5   rougher.input.feed_rate                             14572 non-null  float64
#  6   rougher.input.feed_size                             14478 non-null  float64
#  7   rougher.input.floatbank10_sulfate                   14548 non-null  float64
#  8   rougher.input.floatbank10_xanthate                  14572 non-null  float64
#  9   rougher.state.floatbank10_a_air                     14579 non-null  float64
#  10  rougher.state.floatbank10_a_level                   14579 non-null  float64
#  11  rougher.state.floatbank10_b_air                     14579 non-null  float64
#  12  rougher.state.floatbank10_b_level                   14579 non-null  float64
#  13  rougher.state.floatbank10_c_air                     14579 non-null  float64
#  14  rougher.state.floatbank10_c_level                   14579 non-null  float64
#  15  rougher.state.floatbank10_d_air                     14579 non-null  float64
#  16  rougher.state.floatbank10_d_level                   14579 non-null  float64
#  17  rougher.state.floatbank10_e_air                     14150 non-null  float64
#  18  rougher.state.floatbank10_e_level                   14579 non-null  float64
#  19  rougher.state.floatbank10_f_air                     14579 non-null  float64
#  20  rougher.state.floatbank10_f_level                   14579 non-null  float64
#  21  rougher.input.floatbank11_sulfate                   14543 non-null  float64
#  22  rougher.input.floatbank11_xanthate                  14172 non-null  float64
#  23  rougher.calculation.sulfate_to_au_concentrate       14578 non-null  float64
#  24  rougher.calculation.floatbank10_sulfate_to_au_feed  14578 non-null  float64
#  25  rougher.calculation.floatbank11_sulfate_to_au_feed  14578 non-null  float64
#  26  rougher.calculation.au_pb_ratio                     14579 non-null  float64
#  27  rougher.output.concentrate_au                       14579 non-null  float64
#  28  rougher.output.concentrate_ag                       14579 non-null  float64
#  29  rougher.output.concentrate_pb                       14579 non-null  float64
#  30  rougher.output.concentrate_sol                      14561 non-null  float64
#  31  rougher.output.recovery                             14579 non-null  float64
#  32  rougher.output.tail_au                              14579 non-null  float64
#  33  rougher.output.tail_ag                              14578 non-null  float64
#  34  rougher.output.tail_pb                              14579 non-null  float64
#  35  rougher.output.tail_sol                             14579 non-null  float64
#  36  primary_cleaner.input.sulfate                       14556 non-null  float64
#  37  primary_cleaner.input.depressant                    14551 non-null  float64
#  38  primary_cleaner.input.feed_size                     14579 non-null  float64
#  39  primary_cleaner.input.xanthate                      14518 non-null  float64
#  40  primary_cleaner.state.floatbank8_a_air              14576 non-null  float64
#  41  primary_cleaner.state.floatbank8_a_level            14579 non-null  float64
#  42  primary_cleaner.state.floatbank8_b_air              14576 non-null  float64
#  43  primary_cleaner.state.floatbank8_b_level            14579 non-null  float64
#  44  primary_cleaner.state.floatbank8_c_air              14579 non-null  float64
#  45  primary_cleaner.state.floatbank8_c_level            14579 non-null  float64
#  46  primary_cleaner.state.floatbank8_d_air              14578 non-null  float64
#  47  primary_cleaner.state.floatbank8_d_level            14579 non-null  float64
#  48  primary_cleaner.output.concentrate_au               14579 non-null  float64
#  49  primary_cleaner.output.concentrate_ag               14579 non-null  float64
#  50  primary_cleaner.output.concentrate_pb               14491 non-null  float64
#  51  primary_cleaner.output.concentrate_sol              14314 non-null  float64
#  52  primary_cleaner.output.tail_au                      14579 non-null  float64
#  53  primary_cleaner.output.tail_ag                      14575 non-null  float64
#  54  primary_cleaner.output.tail_pb                      14573 non-null  float64
#  55  primary_cleaner.output.tail_sol                     14534 non-null  float64
#  56  secondary_cleaner.state.floatbank2_a_air            14485 non-null  float64
#  57  secondary_cleaner.state.floatbank2_a_level          14579 non-null  float64
#  58  secondary_cleaner.state.floatbank2_b_air            14557 non-null  float64
#  59  secondary_cleaner.state.floatbank2_b_level          14579 non-null  float64
#  60  secondary_cleaner.state.floatbank3_a_air            14567 non-null  float64
#  61  secondary_cleaner.state.floatbank3_a_level          14579 non-null  float64
#  62  secondary_cleaner.state.floatbank3_b_air            14579 non-null  float64
#  63  secondary_cleaner.state.floatbank3_b_level          14579 non-null  float64
#  64  secondary_cleaner.state.floatbank4_a_air            14574 non-null  float64
#  65  secondary_cleaner.state.floatbank4_a_level          14579 non-null  float64
#  66  secondary_cleaner.state.floatbank4_b_air            14579 non-null  float64
#  67  secondary_cleaner.state.floatbank4_b_level          14579 non-null  float64
#  68  secondary_cleaner.state.floatbank5_a_air            14579 non-null  float64
#  69  secondary_cleaner.state.floatbank5_a_level          14579 non-null  float64
#  70  secondary_cleaner.state.floatbank5_b_air            14579 non-null  float64
#  71  secondary_cleaner.state.floatbank5_b_level          14579 non-null  float64
#  72  secondary_cleaner.state.floatbank6_a_air            14578 non-null  float64
#  73  secondary_cleaner.state.floatbank6_a_level          14579 non-null  float64
#  74  secondary_cleaner.output.tail_au                    14579 non-null  float64
#  75  secondary_cleaner.output.tail_ag                    14578 non-null  float64
#  76  secondary_cleaner.output.tail_pb                    14575 non-null  float64
#  77  secondary_cleaner.output.tail_sol                   13659 non-null  float64
#  78  final.output.concentrate_au                         14579 non-null  float64
#  79  final.output.concentrate_ag                         14578 non-null  float64
#  80  final.output.concentrate_pb                         14578 non-null  float64
#  81  final.output.concentrate_sol                        14387 non-null  float64
#  82  final.output.recovery                               14579 non-null  float64
#  83  final.output.tail_au                                14579 non-null  float64
#  84  final.output.tail_ag                                14578 non-null  float64
#  85  final.output.tail_pb                                14504 non-null  float64
#  86  final.output.tail_sol                               14574 non-null  float64
# dtypes: float64(86), object(1)
# memory usage: 9.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4860 entries, 0 to 4859
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        4860 non-null   object
#  1   rougher.input.feed_au                       4860 non-null   float64
#  2   rougher.input.feed_ag                       4860 non-null   float64
#  3   rougher.input.feed_pb                       4832 non-null   float64
#  4   rougher.input.feed_sol                      4838 non-null   float64
#  5   rougher.input.feed_rate                     4856 non-null   float64
#  6   rougher.input.feed_size                     4816 non-null   float64
#  7   rougher.input.floatbank10_sulfate           4857 non-null   float64
#  8   rougher.input.floatbank10_xanthate          4859 non-null   float64
#  9   rougher.state.floatbank10_a_air             4859 non-null   float64
#  10  rougher.state.floatbank10_a_level           4859 non-null   float64
#  11  rougher.state.floatbank10_b_air             4859 non-null   float64
#  12  rougher.state.floatbank10_b_level           4859 non-null   float64
#  13  rougher.state.floatbank10_c_air             4859 non-null   float64
#  14  rougher.state.floatbank10_c_level           4859 non-null   float64
#  15  rougher.state.floatbank10_d_air             4860 non-null   float64
#  16  rougher.state.floatbank10_d_level           4860 non-null   float64
#  17  rougher.state.floatbank10_e_air             4853 non-null   float64
#  18  rougher.state.floatbank10_e_level           4860 non-null   float64
#  19  rougher.state.floatbank10_f_air             4860 non-null   float64
#  20  rougher.state.floatbank10_f_level           4860 non-null   float64
#  21  rougher.input.floatbank11_sulfate           4852 non-null   float64
#  22  rougher.input.floatbank11_xanthate          4814 non-null   float64
#  23  primary_cleaner.input.sulfate               4859 non-null   float64
#  24  primary_cleaner.input.depressant            4851 non-null   float64
#  25  primary_cleaner.input.feed_size             4860 non-null   float64
#  26  primary_cleaner.input.xanthate              4817 non-null   float64
#  27  primary_cleaner.state.floatbank8_a_air      4859 non-null   float64
#  28  primary_cleaner.state.floatbank8_a_level    4859 non-null   float64
#  29  primary_cleaner.state.floatbank8_b_air      4859 non-null   float64
#  30  primary_cleaner.state.floatbank8_b_level    4859 non-null   float64
#  31  primary_cleaner.state.floatbank8_c_air      4858 non-null   float64
#  32  primary_cleaner.state.floatbank8_c_level    4859 non-null   float64
#  33  primary_cleaner.state.floatbank8_d_air      4858 non-null   float64
#  34  primary_cleaner.state.floatbank8_d_level    4859 non-null   float64
#  35  secondary_cleaner.state.floatbank2_a_air    4734 non-null   float64
#  36  secondary_cleaner.state.floatbank2_a_level  4859 non-null   float64
#  37  secondary_cleaner.state.floatbank2_b_air    4859 non-null   float64
#  38  secondary_cleaner.state.floatbank2_b_level  4859 non-null   float64
#  39  secondary_cleaner.state.floatbank3_a_air    4859 non-null   float64
#  40  secondary_cleaner.state.floatbank3_a_level  4859 non-null   float64
#  41  secondary_cleaner.state.floatbank3_b_air    4859 non-null   float64
#  42  secondary_cleaner.state.floatbank3_b_level  4859 non-null   float64
#  43  secondary_cleaner.state.floatbank4_a_air    4859 non-null   float64
#  44  secondary_cleaner.state.floatbank4_a_level  4859 non-null   float64
#  45  secondary_cleaner.state.floatbank4_b_air    4859 non-null   float64
#  46  secondary_cleaner.state.floatbank4_b_level  4859 non-null   float64
#  47  secondary_cleaner.state.floatbank5_a_air    4859 non-null   float64
#  48  secondary_cleaner.state.floatbank5_a_level  4859 non-null   float64
#  49  secondary_cleaner.state.floatbank5_b_air    4859 non-null   float64
#  50  secondary_cleaner.state.floatbank5_b_level  4859 non-null   float64
#  51  secondary_cleaner.state.floatbank6_a_air    4859 non-null   float64
#  52  secondary_cleaner.state.floatbank6_a_level  4859 non-null   float64
# dtypes: float64(52), object(1)
# memory usage: 2.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   rougher.input.feed_au                               19439 non-null  float64
#  2   rougher.input.feed_ag                               19439 non-null  float64
#  3   rougher.input.feed_pb                               19339 non-null  float64
#  4   rougher.input.feed_sol                              19340 non-null  float64
#  5   rougher.input.feed_rate                             19428 non-null  float64
#  6   rougher.input.feed_size                             19294 non-null  float64
#  7   rougher.input.floatbank10_sulfate                   19405 non-null  float64
#  8   rougher.input.floatbank10_xanthate                  19431 non-null  float64
#  9   rougher.state.floatbank10_a_air                     19438 non-null  float64
#  10  rougher.state.floatbank10_a_level                   19438 non-null  float64
#  11  rougher.state.floatbank10_b_air                     19438 non-null  float64
#  12  rougher.state.floatbank10_b_level                   19438 non-null  float64
#  13  rougher.state.floatbank10_c_air                     19438 non-null  float64
#  14  rougher.state.floatbank10_c_level                   19438 non-null  float64
#  15  rougher.state.floatbank10_d_air                     19439 non-null  float64
#  16  rougher.state.floatbank10_d_level                   19439 non-null  float64
#  17  rougher.state.floatbank10_e_air                     19003 non-null  float64
#  18  rougher.state.floatbank10_e_level                   19439 non-null  float64
#  19  rougher.state.floatbank10_f_air                     19439 non-null  float64
#  20  rougher.state.floatbank10_f_level                   19439 non-null  float64
#  21  rougher.input.floatbank11_sulfate                   19395 non-null  float64
#  22  rougher.input.floatbank11_xanthate                  18986 non-null  float64
#  23  rougher.calculation.sulfate_to_au_concentrate       19437 non-null  float64
#  24  rougher.calculation.floatbank10_sulfate_to_au_feed  19437 non-null  float64
#  25  rougher.calculation.floatbank11_sulfate_to_au_feed  19437 non-null  float64
#  26  rougher.calculation.au_pb_ratio                     19439 non-null  float64
#  27  rougher.output.concentrate_au                       19439 non-null  float64
#  28  rougher.output.concentrate_ag                       19439 non-null  float64
#  29  rougher.output.concentrate_pb                       19439 non-null  float64
#  30  rougher.output.concentrate_sol                      19416 non-null  float64
#  31  rougher.output.recovery                             19439 non-null  float64
#  32  rougher.output.tail_au                              19439 non-null  float64
#  33  rougher.output.tail_ag                              19438 non-null  float64
#  34  rougher.output.tail_pb                              19439 non-null  float64
#  35  rougher.output.tail_sol                             19439 non-null  float64
#  36  primary_cleaner.input.sulfate                       19415 non-null  float64
#  37  primary_cleaner.input.depressant                    19402 non-null  float64
#  38  primary_cleaner.input.feed_size                     19439 non-null  float64
#  39  primary_cleaner.input.xanthate                      19335 non-null  float64
#  40  primary_cleaner.state.floatbank8_a_air              19435 non-null  float64
#  41  primary_cleaner.state.floatbank8_a_level            19438 non-null  float64
#  42  primary_cleaner.state.floatbank8_b_air              19435 non-null  float64
#  43  primary_cleaner.state.floatbank8_b_level            19438 non-null  float64
#  44  primary_cleaner.state.floatbank8_c_air              19437 non-null  float64
#  45  primary_cleaner.state.floatbank8_c_level            19438 non-null  float64
#  46  primary_cleaner.state.floatbank8_d_air              19436 non-null  float64
#  47  primary_cleaner.state.floatbank8_d_level            19438 non-null  float64
#  48  primary_cleaner.output.concentrate_au               19439 non-null  float64
#  49  primary_cleaner.output.concentrate_ag               19439 non-null  float64
#  50  primary_cleaner.output.concentrate_pb               19323 non-null  float64
#  51  primary_cleaner.output.concentrate_sol              19069 non-null  float64
#  52  primary_cleaner.output.tail_au                      19439 non-null  float64
#  53  primary_cleaner.output.tail_ag                      19435 non-null  float64
#  54  primary_cleaner.output.tail_pb                      19418 non-null  float64
#  55  primary_cleaner.output.tail_sol                     19377 non-null  float64
#  56  secondary_cleaner.state.floatbank2_a_air            19219 non-null  float64
#  57  secondary_cleaner.state.floatbank2_a_level          19438 non-null  float64
#  58  secondary_cleaner.state.floatbank2_b_air            19416 non-null  float64
#  59  secondary_cleaner.state.floatbank2_b_level          19438 non-null  float64
#  60  secondary_cleaner.state.floatbank3_a_air            19426 non-null  float64
#  61  secondary_cleaner.state.floatbank3_a_level          19438 non-null  float64
#  62  secondary_cleaner.state.floatbank3_b_air            19438 non-null  float64
#  63  secondary_cleaner.state.floatbank3_b_level          19438 non-null  float64
#  64  secondary_cleaner.state.floatbank4_a_air            19433 non-null  float64
#  65  secondary_cleaner.state.floatbank4_a_level          19438 non-null  float64
#  66  secondary_cleaner.state.floatbank4_b_air            19438 non-null  float64
#  67  secondary_cleaner.state.floatbank4_b_level          19438 non-null  float64
#  68  secondary_cleaner.state.floatbank5_a_air            19438 non-null  float64
#  69  secondary_cleaner.state.floatbank5_a_level          19438 non-null  float64
#  70  secondary_cleaner.state.floatbank5_b_air            19438 non-null  float64
#  71  secondary_cleaner.state.floatbank5_b_level          19438 non-null  float64
#  72  secondary_cleaner.state.floatbank6_a_air            19437 non-null  float64
#  73  secondary_cleaner.state.floatbank6_a_level          19438 non-null  float64
#  74  secondary_cleaner.output.tail_au                    19439 non-null  float64
#  75  secondary_cleaner.output.tail_ag                    19437 non-null  float64
#  76  secondary_cleaner.output.tail_pb                    19427 non-null  float64
#  77  secondary_cleaner.output.tail_sol                   17691 non-null  float64
#  78  final.output.concentrate_au                         19439 non-null  float64
#  79  final.output.concentrate_ag                         19438 non-null  float64
#  80  final.output.concentrate_pb                         19438 non-null  float64
#  81  final.output.concentrate_sol                        19228 non-null  float64
#  82  final.output.recovery                               19439 non-null  float64
#  83  final.output.tail_au                                19439 non-null  float64
#  84  final.output.tail_ag                                19438 non-null  float64
#  85  final.output.tail_pb                                19338 non-null  float64
#  86  final.output.tail_sol                               19433 non-null  float64
# dtypes: float64(86), object(1)
# memory usage: 12.9+ MB

# %%
# Я подсчитал общее число пропущенных значений в обучающем датасете data_train
print(data_train.isnull().sum().sum())
# Out:
# 3050

# %%
# Я подсчитал общее число пропущенных значений в обучающем датасете data_test
print(data_test.isnull().sum().sum())
# Out:
# 375

# %%
# Я подсчитал общее число пропущенных значений в полном датасете data_full
print(data_full.isnull().sum().sum())
# Out:
# 4481

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **КОММЕНТАРИЙ СТУДЕНТА 1:**
#
# Я загрузил три набора данных: data_train, data_test и data_full из соответствующих CSV-файлов. Я использовал метод `head()` для вывода первых нескольких строк каждого набора данных, чтобы ознакомиться с ними. Я также использовал метод `describe()` для получения статистических данных о числовых столбцах каждого набора данных, таких как количество, среднее значение, стандартное отклонение, минимальное и максимальное значения и т.д. Я использовал метод `info()` для выведения информации о каждом столбце в каждом наборе данных, включая общее количество записей, тип данных и количество ненулевых значений в каждом столбце. Я также использовал метод `isnull()` для определения количества пропущенных значений в каждом наборе данных.
#
# </div>

# %% [markdown]
# ### Я проверил, что эффективность обогащения рассчитана правильно. Я вычислил ее на обучающей выборке для признака rougher.output.recovery. Затем я нашел MAE между моими расчетами и значением признака. Теперь я могу сделать выводы на основе полученных результатов.

# %%
# Я рассчитал эффективность обогащения.
C = data_train['rougher.output.concentrate_au']
F = data_train['rougher.input.feed_au']
T = data_train['rougher.output.tail_au']
rougher_recovery = data_train['rougher.output.recovery']
recovery = (C * (F - T)) / (F * (C - T)) * 100

# Я нашёл MAE.
print('MAE =', mean_absolute_error(rougher_recovery, recovery))
# Out:
# MAE = 9.83758577644259e-15

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **КОММЕНТАРИЙ СТУДЕНТА 1:**
#
# Результат “9.73512347450521e-15” означает очень маленькое значение, близкое к нулю. Скорее всего, это означает, что расчетные значения для эффективности обогащения, рассчитанные по формуле, очень близки к фактическим значениям, которые указаны в столбце ‘rougher.output.recovery’ в обучающей выборке. Таким образом, я могу сделать вывод, что эффективность обогащения, рассчитанная по формуле, была рассчитана правильно.
#
# </div>

# %% [markdown]
# ### Я проанализировал признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу они относятся?

# %%
# Я создал множество missing_features с названиями признаков, которые есть в обучающей выборке, но отсутствуют в тестовой выборке, на основе разности множеств.
missing_features = set(data_train.columns) - set(data_test.columns)
print(missing_features)
# Out:
# {'final.output.concentrate_au', 'final.output.concentrate_pb', 'secondary_cleaner.output.tail_au', 'secondary_cleaner.output.tail_ag', 'rougher.output.tail_ag', 'primary_cleaner.output.tail_sol', 'final.output.tail_au', 'rougher.output.tail_au', 'primary_cleaner.output.concentrate_sol', 'secondary_cleaner.output.tail_sol', 'final.output.concentrate_sol', 'primary_cleaner.output.tail_ag', 'rougher.output.concentrate_sol', 'rougher.output.concentrate_au', 'final.output.tail_sol', 'rougher.calculation.floatbank10_sulfate_to_au_feed', 'primary_cleaner.output.concentrate_au', 'rougher.calculation.sulfate_to_au_concentrate', 'final.output.tail_pb', 'primary_cleaner.output.concentrate_ag', 'rougher.calculation.au_pb_ratio', 'rougher.output.tail_sol', 'rougher.output.recovery', 'final.output.recovery', 'secondary_cleaner.output.tail_pb', 'primary_cleaner.output.concentrate_pb', 'final.output.concentrate_ag', 'final.output.tail_ag', 'rougher.output.tail_pb', 'rougher.output.concentrate_pb', 'primary_cleaner.output.tail_au', 'primary_cleaner.output.tail_pb', 'rougher.calculation.floatbank11_sulfate_to_au_feed', 'rougher.output.concentrate_ag'}

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **КОММЕНТАРИЙ СТУДЕНТА 1:**
#
# Эти параметры относятся к различным этапам технологического процесса очистки золотосодержащей руды и представляют собой значения, полученные в ходе измерения технологических параметров. Каждый параметр отражает определенные характеристики очистки, такие как содержание золота или других элементов в концентрате или хвостах, и используются для определения эффективности технологического процесса. К ним можно отнести различные типы данных, такие как числовые, булевы и категориальные, в зависимости от конкретного параметра.
#
# </div>

# %% [markdown]
# ### Проведите предобработку данных

# %%
# Заполняем пропущенные значения методом ffill
data_train.fillna(method='ffill', inplace=True)
data_test.fillna(method='ffill', inplace=True)
data_full.fillna(method='ffill', inplace=True)

# Удаляем дубликаты
data_train.drop_duplicates(inplace=True)
data_test.drop_duplicates(inplace=True)
data_full.drop_duplicates(inplace=True)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **КОММЕНТАРИЙ СТУДЕНТА 1:**
#
# **Вывод:**
#
# - При загрузке данных из CSV файлов я создал три объекта DataFrame: data_train, data_test и data_full. Я использовал методы head(), describe() и info() для просмотра первых строк, статистической информации и общей информации о датасетах.
# - В обучающем датасете data_train я рассчитал значения эффективности обогащения и MAE (среднюю абсолютную ошибку) между рассчитанными и фактическими значениями.
# - Для тестового датасета data_test я создал множество missing_features, содержащее названия признаков, которые есть в обучающей выборке, но отсутствуют в тестовой.
# - Все три датасета были заполнены пропущенными значениями методом ffill и удалены дубликаты.
#
# </div>

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы.

# %%
au_concentrations = data_full[['rougher.input.feed_au', 
                               'rougher.output.concentrate_au', 
                               'primary_cleaner.output.concentrate_au', 
                               'final.output.concentrate_au']]
plt.hist(au_concentrations, bins=50, alpha=0.5, label=['Исходный материал', 'Флотация', 'Первичная очистка', 'Финальный концентрат'])
plt.legend(loc='upper right')
plt.xlabel('Концентрация Au')
plt.ylabel('Количество')
plt.title('Распределение концентрации Au на разных этапах очистки')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА 1:</b><br>
#
# - На этой гистограмме мы можем видеть, что концентрация золота возрастает на каждом этапе очистки, начиная от концентрации в исходном материале до финальной концентрации (Финальный концентрат)
#
# </div>

# %%
ag_concentrations = data_full[['rougher.input.feed_ag', 
                               'rougher.output.concentrate_ag', 
                               'primary_cleaner.output.concentrate_ag', 
                               'final.output.concentrate_ag']]
plt.hist(ag_concentrations, bins=50, alpha=0.5, label=['Исходный материал', 'Флотация', 'Первичная очистка', 'Финальный концентрат'])
plt.legend(loc='upper right')
plt.xlabel('Концентрация Ag')
plt.ylabel('Количество')
plt.title('Распределение концентрации Ag на разных этапах очистки')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА 1:</b><br>
#
# - На выходе получены гистограммы концентрации Ag на каждом из этапов очистки. Из графиков можно сделать следующие выводы:
#
#     - Концентрация Ag в исходном материале (rougher.input.feed_ag) имеет более или менее равномерное распределение в диапазоне от 0 до примерно 15
#     - Концентрация Ag после флотации (rougher.output.concentrate_ag) имеет более сильно скошенное распределение в сторону больших значений, причем пик находится около 20
#     - Концентрация Ag после первичной очистки (primary_cleaner.output.concentrate_ag) имеет распределение, более симметричное по сравнению с предыдущим этапом, но все еще скошенное в сторону больших значений
#     - Концентрация Ag после финальной очистки (final.output.concentrate_ag) имеет распределение, похожее на распределение на первичной очистке, но более симметричное и с более широким диапазоном значений
#
# - Таким образом, мы можем видеть, как концентрация Ag меняется на каждом из этапов очистки, и какое распределение она имеет на каждом из этих этапов
#
# </div>

# %%
pb_concentrations = data_full[['rougher.input.feed_pb', 
                               'rougher.output.concentrate_pb', 
                               'primary_cleaner.output.concentrate_pb', 
                               'final.output.concentrate_pb']]
plt.hist(pb_concentrations.values, bins=50, alpha=0.5, label=['Исходный материал', 
                                                   'Флотация', 
                                                   'Первичная очистка', 
                                                   'Финальная очистка'])
plt.legend(loc='upper right')
plt.title('Концентрация свинца на различных этапах очистки')
plt.xlabel('Концентрация, %')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА 1:</b><br>
#
# - Как видно из гистограммы, концентрация свинца значительно увеличивается на этапе флотации, после чего постепенно снижается на последующих этапах очистки. Однако, даже после финальной очистки концентрация свинца остается выше, чем в исходном материале
#
# </div>

# %% [markdown]
# ### Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.

# %%
# Создадим гистограмму на основе признака "rougher.input.feed_size", что означает размер гранул сырья, подаваемого на этап флотации из обучающего набора данных "data_train" и тестового "data_test"
plt.hist(data_train['rougher.input.feed_size'], bins=50, alpha=0.5, label='train')
plt.hist(data_test['rougher.input.feed_size'], bins=50, alpha=0.5, label='test')
plt.xlabel('Размер гранул сырья')
plt.ylabel('Количество наблюдений')
plt.title('Распределение размеров гранул сырья перед флотацией')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА 1:</b><br>
#
# - Оба графика имеют схожее распределение, с максимальным количеством наблюдений при размерах гранул в диапазоне от примерно 45 до 60
#
# </div>

# %%
# Создадим гистограмму на основе признака "primary_cleaner.input.feed_size", что означает размеру гранул сырья, подаваемого на первый этап очистки из обучающего набора данных "data_train" и тестового "data_test"
plt.hist(data_train['primary_cleaner.input.feed_size'], bins=50, alpha=0.5, label='train')
plt.hist(data_test['primary_cleaner.input.feed_size'], bins=50, alpha=0.5, label='test')
plt.xlabel('Размер гранул сырья')
plt.ylabel('Количество наблюдений')
plt.title('Распределение размеров гранул сырья перед первичной очисткой')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА 1:</b><br>
#
# - Распределения схожи друг с другом и имеют максимальное количество наблюдений в диапазоне размеров гранул от 5 до 10
#
# </div>

# %%
sns.kdeplot(data_train['primary_cleaner.input.feed_size'], label='train')
sns.kdeplot(data_test['primary_cleaner.input.feed_size'], label='test')
plt.xlabel('Размер гранул сырья')
plt.ylabel('Доля относительно датасета')
plt.title('Распределение размеров гранул сырья перед первичной очисткой')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА v.2:</b><br>
#
# - На основании данного графика можно сделать вывод о сходстве распределений размеров гранул сырья перед первичной очисткой на тренировочной и тестовой выборках, что является хорошим знаком для качественного обучения модели
#
# </div>

# %% [markdown]
# ### Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %%
# Функция для удаления аномалий
def drop_rows_with_zero_concentrate(data):
    cols_to_check = ['primary_cleaner.output.concentrate_au',
                     'primary_cleaner.output.concentrate_ag',
                     'primary_cleaner.output.concentrate_pb',
                     'primary_cleaner.output.concentrate_sol',
                     'rougher.output.concentrate_au',
                     'rougher.output.concentrate_ag',
                     'rougher.output.concentrate_pb',
                     'rougher.output.concentrate_sol',
                     'final.output.concentrate_au',
                     'final.output.concentrate_ag',
                     'final.output.concentrate_pb',
                     'final.output.concentrate_sol']
    for col in cols_to_check:
        data = data.drop(data[data[col] < 1].index)
    return data

# Удалим аномалии
data_train = drop_rows_with_zero_concentrate(data_train)

# %%
final_output_concentrate_sum = (data_train['final.output.concentrate_au'] + 
                                      data_train['final.output.concentrate_ag'] + 
                                      data_train['final.output.concentrate_pb'] +
                                      data_train['final.output.concentrate_sol'])
primary_cleaner_output_concentrate_sum = (data_train['primary_cleaner.output.concentrate_au'] + 
                                                data_train['primary_cleaner.output.concentrate_ag'] + 
                                                data_train['primary_cleaner.output.concentrate_pb'] +
                                                data_train['primary_cleaner.output.concentrate_sol'])
rougher_output_concentrate_sum_train = (data_train['rougher.output.concentrate_au'] + 
                                        data_train['rougher.output.concentrate_ag'] + 
                                        data_train['rougher.output.concentrate_pb'] +
                                        data_train['rougher.output.concentrate_sol'])

plt.hist(final_output_concentrate_sum, bins=50, alpha=0.5, label='Финальный концентрат')
plt.hist(primary_cleaner_output_concentrate_sum, bins=50, alpha=0.5, label='Черновой концентрат')
plt.hist(rougher_output_concentrate_sum_train, bins=50, alpha=0.5, label='Сырье')
plt.title('Суммарная концентрация всех веществ на разных стадиях')
plt.xlabel('Суммарная концентрация всех веществ')
plt.ylabel('Количество наблюдений')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА 1:</b><br>
#     <b>Вывод:</b>
#
# - Удалены аномалии
# - Процесс очистки сырья от примесей увеличивает концентрацию ценных металлов в конечном продукте
# - Концентрация золота и серебра возрастает на каждом этапе очистки, начиная от концентрации в исходном материале до финальной концентрации
# - Концентрация свинца также увеличивается на этапе флотации, но затем постепенно снижается на последующих этапах очистки, но все еще остается выше, чем в исходном материале
# - Размеры гранул на разных этапах очистки также имеют схожее распределение, с максимальным количеством наблюдений в диапазоне от 5 до 60
# - Таким образом, процесс очистки является эффективным способом повышения концентрации ценных металлов в конечном продукте
#
# </div>

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Напишите функцию для вычисления итоговой sMAPE.

# %%
def smape(y_true,y_pred):
    # Вычисляем ошибку по формуле SMAPE
    error = np.mean(abs(y_true - y_pred)/((abs(y_true)+abs(y_pred))/2))*100
    # Возвращаем значение ошибки в процентах
    return error

def final_smape(model,rougher_features,rougher_target,final_features,final_target):
    # Вычисляем итоговое значение ошибки на основе SMAPE для признаков rougher.output.recovery и final.output.recovery
    smape_rougher = evaluate_model(model,rougher_features,rougher_target)
    smape_final = evaluate_model(model,final_features,final_target)
    return (0.25*smape_rougher + 0.75*smape_final)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА 1:</b><br>
#
# - Написали функцию smape для измерения среднего абсолютного процентное отклонения sMAPE
# - Написали функцию final_smape для измерения итогового значения ошибки на основе SMAPE для двух признаков: rougher.output.recovery и final.output.recovery
#
# </div>

# %% [markdown]
# ### Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.

# %%
# Подготовка данных
common_features = data_train.drop(missing_features, axis=1)

rougher_features = common_features.drop(["date"], axis=1)
rougher_target = data_train["rougher.output.recovery"]

final_features = common_features.drop(["date"], axis=1)
final_target = data_train["final.output.recovery"]

model_dtr = DecisionTreeRegressor(random_state=42)
model_rfr = RandomForestRegressor(n_estimators=10, random_state=42)
model_lr = LinearRegression()

# Создаем функцию-скорер на основе smape
smape_scorer = make_scorer(smape, greater_is_better=False)

def evaluate_model(model, features, target):
    # Оцениваем качество модели кросс-валидацией
    scores = cross_val_score(model, features, target, cv=5, scoring=smape_scorer)
    return -scores.mean()

# Задаем диапазон значений гиперпараметров
max_depth_range = range(1, 11)
min_samples_leaf_range = range(2, 6)

# Итерируемся по всем значениям гиперпараметров и обучаем модель
for max_depth in max_depth_range:
    for min_samples_leaf in min_samples_leaf_range:
        model_dtr = DecisionTreeRegressor(max_depth=max_depth, min_samples_leaf=min_samples_leaf, random_state=42)
        final_smape_dtr = final_smape(model_dtr,rougher_features,rougher_target,final_features,final_target)
        print("Итоговое sMAPE для модели Дерево решений:",round(final_smape_dtr,2),"%", "при максимальной глубине дерева max_depth:",max_depth, "и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf:",min_samples_leaf)

# final_smape_dtr = final_smape(model_dtr,rougher_features,rougher_target,final_features,final_target)
final_smape_rfr = final_smape(model_rfr,rougher_features,rougher_target,final_features,final_target)
final_smape_lr = final_smape(model_lr,rougher_features,rougher_target,final_features,final_target)


print("Итоговое sMAPE для модели Случайный лес:",round(final_smape_rfr,2),"%")
print("Итоговое sMAPE для модели Линейная регрессия:",round(final_smape_lr,2),"%")
# Out:
# Итоговое sMAPE для модели Дерево решений: 8.46 % при максимальной глубине дерева max_depth: 1 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 2
# Итоговое sMAPE для модели Дерево решений: 8.46 % при максимальной глубине дерева max_depth: 1 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 3
# Итоговое sMAPE для модели Дерево решений: 8.46 % при максимальной глубине дерева max_depth: 1 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 4
# Итоговое sMAPE для модели Дерево решений: 8.46 % при максимальной глубине дерева max_depth: 1 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 5
# Итоговое sMAPE для модели Дерево решений: 8.3 % при максимальной глубине дерева max_depth: 2 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 2
# Итоговое sMAPE для модели Дерево решений: 8.3 % при максимальной глубине дерева max_depth: 2 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 3
# Итоговое sMAPE для модели Дерево решений: 8.3 % при максимальной глубине дерева max_depth: 2 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 4
# Итоговое sMAPE для модели Дерево решений: 8.3 % при максимальной глубине дерева max_depth: 2 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 5
# Итоговое sMAPE для модели Дерево решений: 8.35 % при максимальной глубине дерева max_depth: 3 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 2
# Итоговое sMAPE для модели Дерево решений: 8.35 % при максимальной глубине дерева max_depth: 3 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 3
# Итоговое sMAPE для модели Дерево решений: 8.35 % при максимальной глубине дерева max_depth: 3 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 4
# Итоговое sMAPE для модели Дерево решений: 8.35 % при максимальной глубине дерева max_depth: 3 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 5
# Итоговое sMAPE для модели Дерево решений: 8.6 % при максимальной глубине дерева max_depth: 4 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 2
# Итоговое sMAPE для модели Дерево решений: 8.6 % при максимальной глубине дерева max_depth: 4 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 3
# Итоговое sMAPE для модели Дерево решений: 8.6 % при максимальной глубине дерева max_depth: 4 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 4
# Итоговое sMAPE для модели Дерево решений: 8.6 % при максимальной глубине дерева max_depth: 4 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 5
# Итоговое sMAPE для модели Дерево решений: 8.72 % при максимальной глубине дерева max_depth: 5 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 2
# Итоговое sMAPE для модели Дерево решений: 8.71 % при максимальной глубине дерева max_depth: 5 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 3
# Итоговое sMAPE для модели Дерево решений: 8.81 % при максимальной глубине дерева max_depth: 5 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 4
# Итоговое sMAPE для модели Дерево решений: 8.8 % при максимальной глубине дерева max_depth: 5 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 5
# Итоговое sMAPE для модели Дерево решений: 8.8 % при максимальной глубине дерева max_depth: 6 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 2
# Итоговое sMAPE для модели Дерево решений: 8.84 % при максимальной глубине дерева max_depth: 6 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 3
# Итоговое sMAPE для модели Дерево решений: 8.94 % при максимальной глубине дерева max_depth: 6 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 4
# Итоговое sMAPE для модели Дерево решений: 8.95 % при максимальной глубине дерева max_depth: 6 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 5
# Итоговое sMAPE для модели Дерево решений: 9.36 % при максимальной глубине дерева max_depth: 7 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 2
# Итоговое sMAPE для модели Дерево решений: 10.19 % при максимальной глубине дерева max_depth: 7 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 3
# Итоговое sMAPE для модели Дерево решений: 9.32 % при максимальной глубине дерева max_depth: 7 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 4
# Итоговое sMAPE для модели Дерево решений: 9.39 % при максимальной глубине дерева max_depth: 7 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 5
# Итоговое sMAPE для модели Дерево решений: 9.83 % при максимальной глубине дерева max_depth: 8 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 2
# Итоговое sMAPE для модели Дерево решений: 9.63 % при максимальной глубине дерева max_depth: 8 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 3
# Итоговое sMAPE для модели Дерево решений: 9.54 % при максимальной глубине дерева max_depth: 8 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 4
# Итоговое sMAPE для модели Дерево решений: 9.57 % при максимальной глубине дерева max_depth: 8 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 5
# Итоговое sMAPE для модели Дерево решений: 10.59 % при максимальной глубине дерева max_depth: 9 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 2
# Итоговое sMAPE для модели Дерево решений: 9.86 % при максимальной глубине дерева max_depth: 9 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 3
# Итоговое sMAPE для модели Дерево решений: 9.99 % при максимальной глубине дерева max_depth: 9 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 4
# Итоговое sMAPE для модели Дерево решений: 10.05 % при максимальной глубине дерева max_depth: 9 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 5
# Итоговое sMAPE для модели Дерево решений: 11.18 % при максимальной глубине дерева max_depth: 10 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 2
# Итоговое sMAPE для модели Дерево решений: 10.46 % при максимальной глубине дерева max_depth: 10 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 3
# Итоговое sMAPE для модели Дерево решений: 10.35 % при максимальной глубине дерева max_depth: 10 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 4
# Итоговое sMAPE для модели Дерево решений: 10.31 % при максимальной глубине дерева max_depth: 10 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 5
# Итоговое sMAPE для модели Случайный лес: 9.17 %
# Итоговое sMAPE для модели Линейная регрессия: 8.77 %

# %%
# создание константной модели, которая предсказывает медиану
dummy = DummyRegressor(strategy='median')
final_smape_dummy = final_smape(dummy,rougher_features,rougher_target,final_features,final_target)
print("Итоговое sMAPE для константной модели Dummy:",round(final_smape_dummy,2),"%")

# сравнение sMAPE для модели Дерева решений и константной модели
model_dtr = DecisionTreeRegressor(max_depth=3, min_samples_leaf=3, random_state=42)
final_smape_dtr = final_smape(model_dtr,rougher_features,rougher_target,final_features,final_target)
if final_smape_dtr < final_smape_dummy:
    print("Модель Дерева решений лучше константной модели")
else:
    print("Константная модель лучше модели Дерева решений")
# Out:
# Итоговое sMAPE для константной модели Dummy: 9.0 %
# Модель Дерева решений лучше константной модели

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА v.2:</b><br>
#
# - Модель Дерева решений лучше константной модели - это говорит о том, что мы можем использовать модель Дерева решений
#
# </div>

# %%
# Проверяем лучшую модель RandomForestRegressor на тестовой выборке
# выбираем нужные колонки из data_full
columns_to_merge = ['date', 'rougher.output.recovery', 'final.output.recovery']
data_full = data_full[columns_to_merge]

# объединяем датафреймы по столбцу 'date'
data_test = pd.merge(data_test, data_full, on='date', how='left')

rougher_features_test = data_test.drop(['rougher.output.recovery', 'date'], axis=1)
rougher_target_test = data_test['rougher.output.recovery']

final_features_test = data_test.drop(['final.output.recovery', 'date'], axis=1)
final_target_test = data_test['final.output.recovery']

# Предсказываем значения для тестового набора
model_dtr_test = DecisionTreeRegressor(max_depth=3, min_samples_leaf=3, random_state=42)
final_smape_dtr_test = final_smape(model_dtr_test,rougher_features_test,rougher_target_test,final_features_test,final_target_test)
print("Итоговое sMAPE для модели Дерева решений на тестовых данных:",round(final_smape_dtr_test,2),"%")
# Out:
# Итоговое sMAPE для модели Дерева решений на тестовых данных: 7.43 %

# %%
# создание константной модели, которая предсказывает медиану
final_smape_dtr_test_dummy = final_smape(dummy,rougher_features_test,rougher_target_test,final_features_test,final_target_test)
print("Итоговое sMAPE для константной модели Dummy:",round(final_smape_dtr_test_dummy,2),"%")

# сравнение sMAPE для модели Дерева решений и константной модели
model_dtr = DecisionTreeRegressor(max_depth=3, min_samples_leaf=3, random_state=42)
final_smape_dtr_test = final_smape(model_dtr_test,rougher_features_test,rougher_target_test,final_features_test,final_target_test)
if final_smape_dtr_test < final_smape_dtr_test_dummy:
    print("Модель Дерева решений лучше константной модели")
else:
    print("Константная модель лучше модели Дерева решений")
# Out:
# Итоговое sMAPE для константной модели Dummy: 8.81 %
# Модель Дерева решений лучше константной модели

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА v.2:</b><br>
#
# - Константная модель показывает лучшие результаты, чем модель Дерева решений - это может быть знаком того, что модель Дерева решений не оптимально подобрана для данной задачи и нужно использовать другую модель машинного обучения, например, Случайный лес
#
# </div>

# %%
# создаем модель
model_rfr = RandomForestRegressor(random_state=42)

# задаем сетку параметров для перебора
param_grid = {
    'n_estimators': [50, 100, 200], 
    'max_depth': [5, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# создаем объект GridSearchCV для перебора параметров
grid_search = GridSearchCV(model_rfr, param_grid, cv=5, n_jobs=-1)

# запускаем перебор параметров
grid_search.fit(rougher_features, rougher_target)

# выводим лучшие параметры и оценку качества модели
print("Лучшие параметры модели:", grid_search.best_params_)
print("Оценка качества модели:", grid_search.best_score_)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА v.2:</b><br>
#
# - Найдены лучшие параметры модели Случайный лес: max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=200
#
# </div>

# %%
model_rfr = RandomForestRegressor(random_state=42, max_depth=5,min_samples_leaf=4,min_samples_split=10,n_estimators=200)

final_smape_rfr = final_smape(model_rfr,rougher_features,rougher_target,final_features,final_target)

print("Итоговое sMAPE для модели Случайный лес:",round(final_smape_rfr,2),"%")

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА v.2:</b><br>
#
# - Итоговое sMAPE для модели Случайный лес на обучающих данных: 8.25
#
# </div>

# %%
final_smape_rfr_test = final_smape(model_rfr,rougher_features_test,rougher_target_test,final_features_test,final_target_test)
print("Итоговое sMAPE для модели Случайный лес на тестовых данных:",round(final_smape_rfr_test,2),"%")

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА v.2:</b><br>
#
# - Итоговое sMAPE для модели Случайный лес на тестовых данных: 9.34%
# - Итоговое sMAPE для модели Случайный лес больше, чем итоговое sMAPE для константной модели Dummy: 9.15%
# - Т.к. итоговое sMAPE для модели Случайный лес: 9.34% меньше, чем итоговое sMAPE для модели Дерева решений на тестовых данных: 9.48%, поэтому выбираем модель Случайный лес
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА v.2:</b><br>
#     <b>Вывод:</b>
#
# - Из проведенного анализа можно сделать вывод, что модель дерева решений дала лучший результат на обучающей выборке с итоговым sMAPE: 8.81% при максимальной глубине дерева max_depth: 3 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 3, чем модели линейной регрессии (итоговый sMAPE равен 9.92%) и случайного леса (итоговый sMAPE равен 9.71%)
# - Для проверки модели Дерева решений на тестовой выборке была использована метрика sMAPE, которая показала итоговое значение 9.48%, что говорит о том, что модель хорошо работает и на новых данных
# - После сравнения итогового значения sMAPE на тестовых данных для Дерева решений с константной моделью Dummy был, сделан вывод, что модель Дерева решений нам не подходит и нужно подобрать параметры для модели Случайный лес
# - С помощью GridSearchCV были найдены лучшие параметры модели Случайный лес: max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# - Было получено итоговое sMAPE для модели Случайный лес на обучающих данных: 8.25%
# - Было получено итоговое sMAPE для модели Случайный лес на тестовых данных: 9.34%, что больше, чем у константной модели Dummy 9.15%, но меньше, чем у модели Дерево решений 9.48%. Поэтому была выбрана модель Случайный лес
# - Таким образом, модель Случайный лес может быть использована для прогнозирования эффективности обогащения золотосодержащей руды в процессе производства
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА v.2:</b><br>
#     <b>Общий вывод:</b><br>
#
# - Подготовка данных:
#
#     - При загрузке данных из CSV файлов были созданы три объекта DataFrame: data_train, data_test и data_full. Были использованы методы head(), describe() и info() для просмотра первых строк, статистической информации и общей информации о датасетах
#     - В обучающем датасете data_train были рассчитаны значения эффективности обогащения и MAE (среднюю абсолютную ошибку) между рассчитанными и фактическими значениями
#     - Для тестового датасета data_test было создано множество missing_features, содержащее названия признаков, которые есть в обучающей выборке, но отсутствуют в тестовой
#     - Все три датасета были заполнены пропущенными значениями методом ffill и удалены дубликаты
#
# - Анализ данных:
#
#     - Удалены аномалии
#     - Процесс очистки сырья от примесей увеличивает концентрацию ценных металлов в конечном продукте
#     - Концентрация золота и серебра возрастает на каждом этапе очистки, начиная от концентрации в исходном материале до финальной концентрации
#     - Концентрация свинца также увеличивается на этапе флотации, но затем постепенно снижается на последующих этапах очистки, но все еще остается выше, чем в исходном материале
#     - Размеры гранул на разных этапах очистки также имеют схожее распределение, с максимальным количеством наблюдений в диапазоне от 5 до 60
#     - Таким образом, процесс очистки является эффективным способом повышения концентрации ценных металлов в конечном продукте
#
# - Модель:
#
#     - Модель дерева решений дала лучший результат на обучающей выборке с итоговым sMAPE: 8.81% при максимальной глубине дерева max_depth: 3 и при минимальном количестве объектов (сэмплов) в листе дерева min_samples_leaf: 3, чем модели линейной регрессии (итоговый sMAPE равен 9.92%) и случайного леса (итоговый sMAPE равен 9.71%)
#     - Для проверки модели Дерева решений на тестовой выборке была использована метрика sMAPE, которая показала итоговое значение 9.48%, что говорит о том, что модель хорошо работает и на новых данных
#     - После сравнения итогового значения sMAPE на тестовых данных для Дерева решений с константной моделью Dummy был, сделан вывод, что модель Дерева решений нам не подходит и нужно подобрать параметры для модели Случайный лес
#     - С помощью GridSearchCV были найдены лучшие параметры модели Случайный лес: max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=200
#     - Было получено итоговое sMAPE для модели Случайный лес на обучающих данных: 8.25%
#     - Было получено итоговое sMAPE для модели Случайный лес на тестовых данных: 9.34%, что больше, чем у константной модели Dummy 9.15%, но меньше, чем у модели Дерево решений 9.48%. Поэтому была выбрана модель Случайный лес
#     - Таким образом, модель Случайный лес может быть использована для прогнозирования эффективности обогащения золотосодержащей руды в процессе производства
#
# </div>
